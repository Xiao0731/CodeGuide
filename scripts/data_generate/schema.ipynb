# %% [markdown]
# ## 数据结构 ##

# %% [markdown]
# ### APPS ###

# %%
{
  "source": "APPS",
  "problem_id": 0,
  "title": "",
  "question": "",
  "difficulty": "introductory/interview/competition",
  "url": "",
  "starter_code": "",
  "input_output": {
    "inputs": [],
    "outputs": []
  },
  "reference_solutions": []
}

# %% [markdown]
# ### schema ###

# %% [markdown]
# #### 训练集 ####

# %%
{
  "train_ID": "train_0001"
  "problem_id": 123,
  "url": "..."
  "category": "array", # 十大类别
  "difficulty": "introductory",
  "problem_statement": "",
  "starter_code": "",
  "io_format": {
    "mode": "standard_input | call_based", # 代码模式：OJ/LeetCode
    "inputs": [],
    "outputs": []
  },
  "teaching_answer": {
    "problem_restatement": "", # 题意整理
    "key_observation": "",     # 顿悟
    "step_by_step_plan": [     # 步骤教授
      "",
      "",
      ""
    ],
    "complexity": {             # 复杂度分析
      "time": "",
      "space": ""
    },
    "common_mistakes": [        # 易错点
      "",
      ""
    ],
    "annotated_code": ""        # 带注释的代码
  },
  "quality_tags": {
    "clear_explanation": true,   # 解释是否详尽
    "contains_trap": true,       # 是否包含陷阱
    "python_friendly": true,     # 是否适合用python解题
    "verifiable_by_tests": true  # 是否通过测试
  }
}

# %% [markdown]
# #### 测试集 ####

# %%
{
  "eval_ID": "eval_0001",
  "category": "array",
  "difficulty": "introductory",
  "problem_statement": "",
  "starter_code": "",
  "io_format": {
    "mode": "standard_input | call_based",
    "inputs": [],
    "outputs": []
  },
  "hidden_tests": [
    {
      "input": "",
      "output": ""
    }
  ],
  "rubric": {
    "must_have_sections": [
      "problem_restatement",    # 是否有题意整理
      "key_observation",        # 是否有顿悟
      "step_by_step_plan",      # 是否有按步骤解题
      "complexity",             # 是否有复杂度分析
      "annotated_code"          # 是否有带注释的代码
    ],
    "pedagogy_checks": [        
      "explains why",           # 是否有解释清楚
      "mentions edge cases",    # 是否有提边界条件
      "gives at least one mistake warning"    # 是否有提醒易错点
    ]
  }
}
